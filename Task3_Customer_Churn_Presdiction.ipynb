# %% [markdown]
# <a href="https://colab.research.google.com/github/AdilPasha2/CODSOFT/blob/main/Task3_Customer_Churn_Presdiction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/Churn_Modelling.csv')

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
# ...

# %%
df.drop(['RowNumber'], axis=1, inplace= True)

# %%
df.head()
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0    15634602  Hargrave          619    France  Female   42       2
# 1    15647311      Hill          608     Spain  Female   41       1
# 2    15619304      Onio          502    France  Female   42       8
# 3    15701354      Boni          699    France  Female   39       1
# 4    15737888  Mitchell          850     Spain  Female   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
# 3       0.00              2          0               0         93826.63
# 4  125510.82              1          1               1         79084.10
#
#    Exited
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0

# %%
df['Geography'].value_counts()
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %%
df= df.join(pd.get_dummies(df['Geography'], prefix= 'Geo').astype('int'))

# %%
df.drop(['Geography'], axis=1, inplace= True)

# %%
df.head()
# Out:
#    CustomerId   Surname  CreditScore  Gender  Age  Tenure    Balance  \
# 0    15634602  Hargrave          619  Female   42       2       0.00
# 1    15647311      Hill          608  Female   41       1   83807.86
# 2    15619304      Onio          502  Female   42       8  159660.80
# 3    15701354      Boni          699  Female   39       1       0.00
# 4    15737888  Mitchell          850  Female   43       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# 0              1          1               1        101348.88       1
# 1              1          0               1        112542.58       0
# 2              3          1               0        113931.57       1
# 3              2          0               0         93826.63       0
# 4              1          1               1         79084.10       0
#
#    Geo_France  Geo_Germany  Geo_Spain
# 0           1            0          0
# 1           0            0          1
# ...

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      5457
# Female    4543
# Name: count, dtype: int64

# %%
df['Gender']= df['Gender'].astype('str').apply(lambda x: 1 if x=='Female' else 0)

# %%
df['Gender'].value_counts()
# Out:
# Gender
# 0    5457
# 1    4543
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    CustomerId   Surname  CreditScore  Gender  Age  Tenure    Balance  \
# 0    15634602  Hargrave          619       1   42       2       0.00
# 1    15647311      Hill          608       1   41       1   83807.86
# 2    15619304      Onio          502       1   42       8  159660.80
# 3    15701354      Boni          699       1   39       1       0.00
# 4    15737888  Mitchell          850       1   43       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# 0              1          1               1        101348.88       1
# 1              1          0               1        112542.58       0
# 2              3          1               0        113931.57       1
# 3              2          0               0         93826.63       0
# 4              1          1               1         79084.10       0
#
#    Geo_France  Geo_Germany  Geo_Spain
# 0           1            0          0
# 1           0            0          1
# ...

# %%
df.columns
# Out:
# Index(['CustomerId', 'Surname', 'CreditScore', 'Gender', 'Age', 'Tenure',
#        'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
#        'EstimatedSalary', 'Exited', 'Geo_France', 'Geo_Germany', 'Geo_Spain'],
#       dtype='object')

# %%
df[[ 'CustomerId', 'CreditScore', 'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
       'IsActiveMember', 'EstimatedSalary', 'Exited']].corr().style.background_gradient()
# Removed 'Surname' and 'Geography' columns as they are not numerical and cannot be used to calculate correlation
# Out:
# <style type="text/css">
# #T_9b9ac_row0_col0, #T_9b9ac_row1_col1, #T_9b9ac_row2_col2, #T_9b9ac_row3_col3, #T_9b9ac_row4_col4, #T_9b9ac_row5_col5, #T_9b9ac_row6_col6, #T_9b9ac_row7_col7, #T_9b9ac_row8_col8, #T_9b9ac_row9_col9, #T_9b9ac_row10_col10 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_9b9ac_row0_col1, #T_9b9ac_row5_col1, #T_9b9ac_row6_col0, #T_9b9ac_row9_col4 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_9b9ac_row0_col2, #T_9b9ac_row0_col9, #T_9b9ac_row1_col2, #T_9b9ac_row1_col3, #T_9b9ac_row3_col0, #T_9b9ac_row4_col1, #T_9b9ac_row5_col9, #T_9b9ac_row6_col9, #T_9b9ac_row9_col1 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_9b9ac_row0_col3, #T_9b9ac_row4_col7, #T_9b9ac_row6_col1 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# ...

# %%
 X= df[['CreditScore', 'Gender', 'Age', 'Tenure',
       'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
       'EstimatedSalary', 'Geo_France', 'Geo_Germany', 'Geo_Spain']]
y= df['Exited']

# %% [markdown]
# Preprocessing

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import  train_test_split
sc= StandardScaler()
X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=0.2)
X_train_scld= sc.fit_transform(X_train)
X_test_scld= sc.transform(X_test)

# %%
#RANDOM FOREST
from sklearn.ensemble import RandomForestClassifier
rfc= RandomForestClassifier(n_estimators=100, criterion='gini')
rfc.fit(X_train_scld, y_train)
y_pred_rfc= rfc.predict(X_test_scld)
y_pred_rfc
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import confusion_matrix
cm_rfc= confusion_matrix(y_test, y_pred_rfc)
cm_rfc= pd.DataFrame(cm_rfc)
cm_rfc
# Out:
#       0    1
# 0  1539   46
# 1   232  183

# %%
from sklearn.metrics import accuracy_score
acc_rfc= accuracy_score(y_test, y_pred_rfc)
print('Accuracy of Random Forest Classifier is: ', acc_rfc)
# Out:
# Accuracy of Random Forest Classifier is:  0.861
